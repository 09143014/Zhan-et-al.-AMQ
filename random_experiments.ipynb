# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import import_ipynb

import RL_attacker_polling_nn as ctrl_mod
import RL_attacker_polling_AMQ1 as exp_mod_AMQ1
import RL_attacker_polling_AMQ2 as exp_mod_AMQ2

plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 20

def norm_curve_from_history(vector_list, max_steps=10000):
    if not vector_list:
        return None, None
    arr = np.array(vector_list[:max_steps], dtype=float)
    final_vec = arr[-1]
    diffs = np.linalg.norm(arr - final_vec, axis=1)
    if diffs[0] == 0:
        norm_diffs = np.zeros_like(diffs)
    else:
        norm_diffs = diffs / diffs[0]
    steps = np.arange(len(norm_diffs))
    return steps, norm_diffs

def run_single_experiment(i, sim_time=2000.0, max_steps=10000, output_dir='outputs', fig_dir='figures'):
    rng = np.random.default_rng(1000 + i)
    arrival_rates = rng.uniform(4.0, 5.0, size=3).tolist()
    service_rate = float(rng.uniform(23.0, 26.0))
    ini_jobs_list = [10, 10, 10]

    np.random.seed(2000 + i)
    ctrl_sys = ctrl_mod.PollingSystem(
        queue_nums=3,
        arrival_rates=arrival_rates,
        ini_jobs_list=ini_jobs_list,
        service_rate=service_rate,
        switch_time=0.1,
        simulation_time=sim_time,
    )
    ctrl_sys.run_simulation()

    np.random.seed(3000 + i)
    amq1_train = exp_mod_AMQ1.PollingSystem(
        queue_nums=3,
        arrival_rates=arrival_rates,
        ini_jobs_list=ini_jobs_list,
        service_rate=service_rate,
        switch_time=0.1,
        simulation_time=sim_time,
    )
    amq1_train.run_simulation()
    optimal_wk_amq1 = amq1_train.rl_history[-1]['w']

    amq1_sys = exp_mod_AMQ1.PollingSystemWithFixedPolicy(
        queue_nums=3,
        arrival_rates=arrival_rates,
        ini_jobs_list=ini_jobs_list,
        service_rate=service_rate,
        switch_time=0.1,
        simulation_time=sim_time,
        optimal_wk=optimal_wk_amq1,
    )
    amq1_sys.run_simulation_with_fixed_policy()

    np.random.seed(10000 + i)
    amq2_train = exp_mod_AMQ2.PollingSystem(
        queue_nums=3,
        arrival_rates=arrival_rates,
        ini_jobs_list=ini_jobs_list,
        service_rate=service_rate,
        switch_time=0.1,
        simulation_time=sim_time,
    )
    amq2_train.run_simulation()
    optimal_wk_amq2 = amq2_train.rl_history[-1]['w']

    amq2_sys = exp_mod_AMQ2.PollingSystemWithFixedPolicy(
        queue_nums=3,
        arrival_rates=arrival_rates,
        ini_jobs_list=ini_jobs_list,
        service_rate=service_rate,
        switch_time=0.1,
        simulation_time=sim_time,
        optimal_wk=optimal_wk_amq2,
    )
    amq2_sys.run_simulation_with_fixed_policy()

    steps_nnq, curve_nnq = norm_curve_from_history([rec['params'] for rec in ctrl_sys.rl_history], max_steps=max_steps)
    steps_amq1, curve_amq1 = norm_curve_from_history([rec['w'] for rec in amq1_train.rl_history], max_steps=max_steps)
    steps_amq2, curve_amq2 = norm_curve_from_history([rec['w'] for rec in amq2_train.rl_history], max_steps=max_steps)

    if curve_nnq is None:
        curve_nnq = np.array([])
    if curve_amq1 is None:
        curve_amq1 = np.array([])
    if curve_amq2 is None:
        curve_amq2 = np.array([])

    os.makedirs(output_dir, exist_ok=True)
    os.makedirs(fig_dir, exist_ok=True)

    np.savetxt(os.path.join(output_dir, f'NNQ_{i+50}.out'), curve_nnq, fmt='%.8f')
    np.savetxt(os.path.join(output_dir, f'AMQ1_{i+50}.out'), curve_amq1, fmt='%.8f')
    np.savetxt(os.path.join(output_dir, f'AMQ2_{i+50}.out'), curve_amq2, fmt='%.8f')

    plt.figure(figsize=(10, 6))
    if steps_nnq is not None:
        plt.plot(steps_nnq, curve_nnq, label='NNQ(Baseline)', color='red', linewidth=2)
    if steps_amq1 is not None:
        plt.plot(steps_amq1, curve_amq1, label='AMQ1(Our method)', color='green', linewidth=2)
    if steps_amq2 is not None:
        plt.plot(steps_amq2, curve_amq2, label='AMQ2(Our method)', color='purple', linewidth=2)

    plt.xlabel('Update step')
    plt.ylabel('Normalized distance to limit')
    plt.title(f'Experiment {i} (3 queues)')
    plt.ylim(0.0, 1.05)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    fig_path = os.path.join(fig_dir, f'convergence_{i}.png')
    plt.savefig(fig_path, dpi=200)
    plt.close()

    return arrival_rates, service_rate, fig_path

n_experiments = 50
sim_time = 2000.0
max_steps = 10000
output_dir = 'outputs'
fig_dir = 'figures'

for i in range(1, n_experiments + 1):
    arrival_rates, service_rate, fig_path = run_single_experiment(
        i, sim_time=sim_time, max_steps=max_steps, output_dir=output_dir, fig_dir=fig_dir
    )
    print(f'Experiment {i}: arrival_rates={arrival_rates}, service_rate={service_rate:.3f}, figure={fig_path}')
# Out:
# Experiment 1: arrival_rates=[4.612594928569951, 4.015700467820332, 4.1876895768819296], service_rate=25.574, figure=figures_new\convergence_1.png
# Experiment 2: arrival_rates=[4.380821159483116, 4.357189337670947, 4.747612317068191], service_rate=24.168, figure=figures_new\convergence_2.png
# Experiment 3: arrival_rates=[4.187757368268634, 4.256705810218822, 4.494679327188852], service_rate=24.982, figure=figures_new\convergence_3.png
# Experiment 4: arrival_rates=[4.000880452740715, 4.130151312127632, 4.138477365298591], service_rate=24.142, figure=figures_new\convergence_4.png
# Experiment 5: arrival_rates=[4.082219173067894, 4.930562042388604, 4.28728402836777], service_rate=24.916, figure=figures_new\convergence_5.png
# Experiment 6: arrival_rates=[4.336921433572824, 4.600856943799655, 4.297831299409175], service_rate=23.713, figure=figures_new\convergence_6.png
# Experiment 7: arrival_rates=[4.071224937460886, 4.815980345177943, 4.642928512918657], service_rate=23.590, figure=figures_new\convergence_7.png
# Experiment 8: arrival_rates=[4.167252749054619, 4.813050747728779, 4.217432829214242], service_rate=25.951, figure=figures_new\convergence_8.png
# Experiment 9: arrival_rates=[4.056500462053439, 4.326915587672862, 4.049851462073198], service_rate=23.844, figure=figures_new\convergence_9.png
# Experiment 10: arrival_rates=[4.094992282961572, 4.535805731236843, 4.917676733113461], service_rate=25.944, figure=figures_new\convergence_10.png
# Experiment 11: arrival_rates=[4.284124840350437, 4.5633235355093955, 4.212600134653989], service_rate=23.246, figure=figures_new\convergence_11.png
# Experiment 12: arrival_rates=[4.306320483270639, 4.7806466843779925, 4.2384364195536754], service_rate=25.581, figure=figures_new\convergence_12.png
# Experiment 13: arrival_rates=[4.794492915306188, 4.078979471574256, 4.672659591296769], service_rate=24.343, figure=figures_new\convergence_13.png
# Experiment 14: arrival_rates=[4.4355240016228, 4.585702305300415, 4.89796480698504], service_rate=25.978, figure=figures_new\convergence_14.png
# Experiment 15: arrival_rates=[4.359902935234058, 4.607067828607366, 4.641305119817779], service_rate=23.279, figure=figures_new\convergence_15.png
# Experiment 16: arrival_rates=[4.227991596712186, 4.442693991094312, 4.3536239538847274], service_rate=24.739, figure=figures_new\convergence_16.png
# Experiment 17: arrival_rates=[4.918351754310276, 4.821331873633815, 4.972579392077101], service_rate=24.799, figure=figures_new\convergence_17.png
# Experiment 18: arrival_rates=[4.593975449188689, 4.4549590756951085, 4.871513887753027], service_rate=25.443, figure=figures_new\convergence_18.png
# Experiment 19: arrival_rates=[4.216926858606591, 4.395995047893723, 4.466884164250881], service_rate=25.486, figure=figures_new\convergence_19.png
# Experiment 20: arrival_rates=[4.578700242995861, 4.283675281288201, 4.075692778305317], service_rate=25.121, figure=figures_new\convergence_20.png
# Experiment 21: arrival_rates=[4.374388142529123, 4.080851412722342, 4.991463375641739], service_rate=23.339, figure=figures_new\convergence_21.png
# Experiment 22: arrival_rates=[4.000526645424316, 4.9184167560562475, 4.589814439779508], service_rate=24.938, figure=figures_new\convergence_22.png
# Experiment 23: arrival_rates=[4.338869080008526, 4.905898735082677, 4.909601951170362], service_rate=25.242, figure=figures_new\convergence_23.png
# Experiment 24: arrival_rates=[4.32246196911657, 4.258352810022951, 4.37031181414829], service_rate=25.655, figure=figures_new\convergence_24.png
# Experiment 25: arrival_rates=[4.821117366602715, 4.6290074949252205, 4.16214494857259], service_rate=23.773, figure=figures_new\convergence_25.png
# Experiment 26: arrival_rates=[4.170737195904389, 4.595117264567321, 4.1945701361409355], service_rate=23.107, figure=figures_new\convergence_26.png
# Experiment 27: arrival_rates=[4.027974556111119, 4.562145643410405, 4.565162061109393], service_rate=23.035, figure=figures_new\convergence_27.png
# Experiment 28: arrival_rates=[4.816171078612689, 4.386016443582965, 4.6753121623629665], service_rate=23.544, figure=figures_new\convergence_28.png
# Experiment 29: arrival_rates=[4.836777336326484, 4.82293612233418, 4.049196536166452], service_rate=23.552, figure=figures_new\convergence_29.png
# Experiment 30: arrival_rates=[4.236864747798621, 4.025187097888606, 4.812819129056071], service_rate=24.725, figure=figures_new\convergence_30.png
# Experiment 31: arrival_rates=[4.692566914459723, 4.950490227172194, 4.662154671339485], service_rate=25.035, figure=figures_new\convergence_31.png
# Experiment 32: arrival_rates=[4.87774000629479, 4.234690432115236, 4.996491645488024], service_rate=25.140, figure=figures_new\convergence_32.png
# Experiment 33: arrival_rates=[4.82813812713092, 4.872997505219752, 4.920661748974553], service_rate=24.877, figure=figures_new\convergence_33.png
# Experiment 34: arrival_rates=[4.9802613401798395, 4.161104775224307, 4.077576107319769], service_rate=25.762, figure=figures_new\convergence_34.png
# Experiment 35: arrival_rates=[4.319890475877803, 4.38013376803603, 4.789396384775255], service_rate=25.830, figure=figures_new\convergence_35.png
# Experiment 36: arrival_rates=[4.29405814487842, 4.800922003109723, 4.496683930353651], service_rate=23.124, figure=figures_new\convergence_36.png
# Experiment 37: arrival_rates=[4.3223334228146, 4.309058886012116, 4.6090307209028], service_rate=24.364, figure=figures_new\convergence_37.png
# Experiment 38: arrival_rates=[4.326756469310928, 4.098521128852415, 4.393728269324694], service_rate=24.147, figure=figures_new\convergence_38.png
# Experiment 39: arrival_rates=[4.869322888674206, 4.480621094372861, 4.553894417570729], service_rate=25.286, figure=figures_new\convergence_39.png
# Experiment 40: arrival_rates=[4.830190258171471, 4.781775621254645, 4.711663154035246], service_rate=25.047, figure=figures_new\convergence_40.png
# Experiment 41: arrival_rates=[4.901455399785464, 4.401623887318053, 4.883855188538338], service_rate=24.330, figure=figures_new\convergence_41.png
# Experiment 42: arrival_rates=[4.357408481825476, 4.372208658840272, 4.576003662341954], service_rate=25.241, figure=figures_new\convergence_42.png
# Experiment 43: arrival_rates=[4.167326596256694, 4.102064149986782, 4.39821483671471], service_rate=25.598, figure=figures_new\convergence_43.png
# Experiment 44: arrival_rates=[4.012370483313536, 4.858467603055431, 4.032060032710207], service_rate=25.773, figure=figures_new\convergence_44.png
# Experiment 45: arrival_rates=[4.848475914614054, 4.302382525577093, 4.719430300975364], service_rate=24.678, figure=figures_new\convergence_45.png
# Experiment 46: arrival_rates=[4.0879132542805285, 4.813293072507513, 4.654970865134974], service_rate=24.405, figure=figures_new\convergence_46.png
# Experiment 47: arrival_rates=[4.553363193323751, 4.425037349532871, 4.329218240754939], service_rate=24.714, figure=figures_new\convergence_47.png
# Experiment 48: arrival_rates=[4.728211816103349, 4.118461987452872, 4.941510540845737], service_rate=23.655, figure=figures_new\convergence_48.png
# Experiment 49: arrival_rates=[4.258174353730881, 4.547013084359887, 4.777707252958289], service_rate=25.189, figure=figures_new\convergence_49.png
# Experiment 50: arrival_rates=[4.49952867309165, 4.29790771146925, 4.9960338992998965], service_rate=23.256, figure=figures_new\convergence_50.png
